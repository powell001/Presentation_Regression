# %% [markdown]
# # Overview
#
# 1. Test the tools to download, munge, model and compare various methods to forecast crop yields.
# 2. Flexibility in terms of the years (train/test), states, methods (trend/arima/ml) and crops used.
# 3. Automate model development with machine learning.

# %% [markdown]
# # Goal
#
# 1. Our goal is to build a basic soybean yield model to predict the coming year's yield of that crop.  We will use features such as temperature (avg) and precipitation, US state, NDVI (measure of quality), podcount and test a shift operator to test the hypothesis that technolical change in the last few years has significantly, on linearly, increased yields

# %% [markdown]
# 1. Yearly yields:
#
#     <font size="3"> $$ Yields_{y} \sim Year_{y} + PodCount_{m} + State + Temp_{m} + Precip_{m} + Quality_{m} + Droughts_{m} + Shifts_{y} + error_{y} $$ </font>

# %% [markdown]
# # Long-term Goals:
# 1. Automate process of modeling yield forecasts and other analyses.
# 2. Incorporate global data.
# 3. Provide a range of forecasts for comparison.

# %% [markdown]
# # Immediate Goals:
# 1. Use US data to forecast soybean yields.
# 2. Automate downloading of data and model scoring.
# 3. Provide figures.
# 4. Test and compare several forecasting methods.

# %% [markdown]
# # <u>Features</u>

# %% [markdown]
# ## Yields (What we want to explain)
#
# ### Hypothsis: Historical yields are a good indicator of future yields.
#
# 1. Plots clearly show a significant trend.
# 2. Nonlinear (quadratic) term picks up rate of increase.
# 3. Look at all major soybean producing states.
# 4. Not accounting for irrigated vs not irrigated, data not good enough.

# %% [markdown]
# ## Pod Count
#
# ### Hypothesis: A good intermediate pod count indicates a good final yield.
#
# 1. We aren't interested in the final pod count, rather the intermediate counts as a way to predict the final yields (which is highly related to the count).
# 2. So we need the pod counts for several intermediate months.
# 3. Available on a monthly basis, starting late in the year (Sep?).

# %% [markdown]
# ## Weather Features
#
# 1. Min
# 2. Max
# 3. Precip
#
# ### These are our main features besides Year.
#
# 1. Bad weather in particular months will damage the soybean crops.
# 2. Try to identify patterns in extreme events.
# 3. Polynomials and interactions.

# %% [markdown]
# ## Quality of Crop
# 1. This is another feature examining the quality of a crop at a particular moment.
# 2. Available on a semi-weekly basis.
# 3. Not many years available and rather spotty.  John suggested that the quality of these measures isn't good, are there other measures?

# %% [markdown]
# ## Drought Measures
# 1. PDSI
# 2. PHDI
# 3. PM
# 4. PZ

# %% [markdown]
# ### Lasso and Ridge regression
#
# 1. Let the model choose the most important features.
# 2. Play with the hyperparameters.

# %% [markdown]
# ## Things to try
#
# 1. Ran initial models to get a feel for the data.
# 2. Tried simple models based on weather variables.
# 3. Add quality features.
# 4. Add irrigated vs non-irrigated.
# 5. Added drought features.
# 6. VIF to eliminate multi-collinearity.
# 3. Try all data, use Lasso, Ridge.

# %% [markdown]
# # <u>Modeling Process</u>

# %% [markdown]
# 1. Notebooks to download each feature and put the data into a "model ready" state.
#     Presentation_01/features
#         a. NASS yield and acre data
#         b. NASS quality measure
#         c. NASS pod count
#         d. NOAA precip, max, min temp
#         e. NOAA drought measure
#     Munged data sent to another file
# 2. A notebook to combine features (joinFeatures.ipynb).
#     Presentation_01/joinFeatures.ipynb
# 3. A notebook to perform model selection, e.g. ridge and lasso regressions (featureSelection.iypnb).
#     Presentation_01/featureSelection.ipynb
# 4. This notebook, which loops over various years and states, performs regressions, and summarize and compares outputs.
#     Presentation_0b1/Project_MainFile.ipynb
# 5. A helper_Functions.ipynb to hold functions that will otherwise obscure more relevant code.
#     Presentation_01/helper_Functions.ipynb

# %% [markdown]
# # <u>Modeling Considerations</u>
# 1.  <u>Training vs Testing, building the perfect model on the training data.</u>
# 2.  <u>Evaluating model performance (do we want to understand a process or forecast).</u>
# 3.  <u>Show me the picture.</u>

# %% [markdown]
# # <u>Models</u>

# %% [markdown]
# ### Imports and general settings

# %%
#Standard packages
import ipynb
from ipynb.fs.full.joinFeatures import mergedData
from ipynb.fs.full.helper_Functions import descriptions1, mse1, mae1, myLasso, bokehFig
import os
import matplotlib.pyplot as plt
import warnings
import pandas as pd
warnings.filterwarnings('ignore')
import numpy as np

#Regressions
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.graphics.regressionplots import plot_leverage_resid2

#Functional programming tools
from functools import reduce

#Scikit learn
from sklearn.feature_selection import VarianceThreshold
from sklearn import linear_model 
from sklearn.feature_selection import SelectFromModel
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import PolynomialFeatures

#Bokeh, interactive figures
from bokeh.io import curdoc
from bokeh.layouts import column, row
from bokeh.models import ColumnDataSource, DataRange1d, Select
from bokeh.palettes import Blues4
from bokeh.plotting import figure, show, output_file, output_notebook
from bokeh.palettes import Spectral11, colorblind, Inferno, BuGn, brewer
from bokeh.models import HoverTool, value, LabelSet, Legend, ColumnDataSource,LinearColorMapper,BasicTicker, PrintfTickFormatter, ColorBar
from bokeh.plotting import figure
from bokeh.resources import CDN
from bokeh.embed import file_html
#print(os.listdir("./"))
output_notebook()
plt.rc("figure", figsize=(25,12))
plt.rc("font", size=10)
TOOLS = 'save,pan,box_zoom,reset,wheel_zoom,hover'
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1258">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Import merged data, combine based on year key.

# %%
#From notebook joinFeatures
allData1 = mergedData()
# Out:
# model_allStates_maxTemp1.csv
# model_allStates_minTemp1.csv
# model_allStates_pdsi1.csv
# model_allStates_pmdi1.csv
# model_allStates_podcount.csv
# model_allStates_precip.csv
# model_allStates_quality.csv
# model_allStates_yields.csv
# model_allStates_zndx1.csv

# %%
allData1[allData1["State"] == "IOWA"]
#print(allData1.shape)
# Out:
#      State  Maxtemp_May  Maxtemp_Jun  Maxtemp_Jul  Maxtemp_Aug  Maxtemp_Sep  \
# Year
# 1895  IOWA         73.9         81.9         85.1         84.9         79.4
# 1896  IOWA         76.6         82.0         84.4         82.7         68.5
# 1897  IOWA         71.1         79.9         87.2         80.3         84.3
# 1898  IOWA         70.0         81.5         85.9         83.5         77.0
# 1899  IOWA         71.1         81.3         84.7         85.4         75.1
# ...    ...          ...          ...          ...          ...          ...
# 2016  IOWA         70.9         84.8         82.6         81.9         77.8
# 2017  IOWA         69.8         83.6         85.8         78.8         79.1
# 2018  IOWA         78.7         83.1         83.8         82.3         75.9
# 2019  IOWA         66.6         79.7         85.2         79.9         78.0
# 2020  IOWA         67.3         83.7         85.9         84.2          NaN
#
#       Maxtemp_Oct  Mintemp_May  Mintemp_Jun  Mintemp_Jul  ...  \
# Year                                                      ...
# 1895         58.6         48.0         56.6         58.1  ...
# 1896         59.4         53.8         57.0         60.2  ...
# 1897         68.6         44.6         56.5         62.9  ...
# 1898         56.2         48.0         60.1         59.8  ...
# 1899         69.0         48.1         59.0         60.2  ...
# ...           ...          ...          ...          ...  ...
# 2016         66.3         48.1         61.2         63.1  ...
# 2017         63.4         47.2         58.6         63.6  ...
# 2018         58.3         55.3         63.1         62.4  ...
# 2019         57.2         46.6         58.9         65.0  ...
# 2020          NaN         47.9         62.1         64.7  ...
#
#       WEEK #35PCT VERY POOR  WEEK #40PCT VERY POOR  Yield  Zndx1_May  \
# Year
# 1895                    NaN                    NaN    NaN       -1.0
# 1896                    NaN                    NaN    NaN        2.4
# 1897                    NaN                    NaN    NaN       -2.1
# 1898                    NaN                    NaN    NaN        0.9
# 1899                    NaN                    NaN    NaN        2.8
# ...                     ...                    ...    ...        ...
# 2016                    1.0                    1.0   60.0        0.7
# 2017                    3.0                    3.0   57.0        1.4
# 2018                    2.0                    3.0   56.0       -0.1
# 2019                    3.0                    2.0   55.0        6.0
# 2020                    6.0                    NaN   54.0        1.2
#
#       Zndx1_Jun  Zndx1_Jul  Zndx1_Aug  Zndx1_Sep  Zndx1_Oct  Year
# Year
# 1895       -0.5   -2.0e-01        0.6       -0.8   -1.7e+00  1895
# 1896       -1.6    3.8e+00        0.1        1.6    2.5e+00  1896
# 1897       -0.7   -1.0e+00       -2.1       -3.2   -2.9e+00  1897
# 1898       -0.4   -1.0e+00       -0.7       -1.4    1.9e+00  1898
# 1899        0.6   -3.5e-01       -0.5       -2.8   -1.5e+00  1899
# ...         ...        ...        ...        ...        ...   ...
# 2016       -1.6    2.9e+00        3.1        3.4    5.0e-02  2016
# 2017       -1.6   -1.2e+00        0.1       -2.1    3.3e+00  2017
# 2018        3.0   -6.0e-02        3.3        5.8    4.3e+00  2018
# 2019       -0.8   -4.5e-01       -0.3        2.3    4.2e+00  2019
# 2020       -0.1   -1.1e+00       -3.5        NaN        NaN  2020
#
# [126 rows x 57 columns]

# %% [markdown]
# ### Look at data!

# %%
iowa1 = allData1[allData1["State"] == "IOWA"]
p = bokehFig(iowa1)
show(p)
# Out:
#   <div class="bk-root" id="bcf5b0cb-4ff6-41f8-bf2c-7c18f9d64a9a" data-root-id="1259"></div>

# %% [markdown]
# ### Add dummy variable

# %%
allData1["YearDummy2005"] = 0
allData1.loc[allData1.Year > 2005, 'YearDummy2005'] = 1

allData1["YearDummy1980"] = 0
allData1.loc[allData1.Year > 1980, 'YearDummy1980'] = 1

allData1["YearDummy2013"] = 0
allData1.loc[allData1.Year > 2013, 'YearDummy2013'] = 1

# %% [markdown]
# ### Which states and years to train and test

# %%
testYear  = 2018 #build model on years before this year, this is the training set
startYear = 1800 #grab all years
finalYear = 2021

#statesofInterest = ['IOWA', 'INDIANA', 'ILLINOIS', 'KANSAS', 'MINNESOTA', 'MISSOURI', 'NEBRASKA', 'NORTH DAKOTA', 'SOUTH DAKOTA', 'OHIO']
statesofInterest = ['IOWA', 'INDIANA', 'ILLINOIS', 'MINNESOTA', 'OHIO']
#statesofInterest = ['IOWA']

# %% [markdown]
# ### Start loops over model per state

# %%
stateResults = []
verbose1 = True
for index1, state1 in enumerate(statesofInterest):
    myGuesses = []
    
    if verbose1 == True:
        # print("index: ", index1)
        print("state: ", state1)
    
    stData = allData1[allData1["State"] == state1]
    trainData = stData[stData["Year"] < testYear]
    testData = stData[stData["Year"]  >= testYear]
    
    if verbose1 == False:
         print("train: ", trainData.shape)
         print("train: ", testData.shape)    
    
    ########## Real ##########
    myGuesses.append(pd.DataFrame({"Observed": testData["Yield"]}))
    
    ########## Year Only ##########
    model = smf.ols('Yield ~ Year', data=trainData).fit()
    predictions =  model.predict(testData) # predict out of sample()
    
    myGuesses.append(pd.DataFrame({"year_only" : predictions}))
    
    if verbose1 == False:
        descriptions1("year_only", model, predictions)
    
    
    ########## Year + Year² ##########
    model = smf.ols('Yield ~ Year + I(Year**2)', data=trainData).fit()
    #model = smf.ols('Yield ~ Year + I(Year**2) + YearDummy2013', data=trainData).fit()
    predictions =  model.predict(testData) # predict out of sample
    
    myGuesses.append(pd.DataFrame({"year__sq" : predictions}))
    
    if verbose1 == False:
        descriptions1("year_sq", model, predictions)
        
    ########## Max Temps ##########
    model = smf.ols('Yield ~ Year + I(Year**2) + Maxtemp_Jun + Maxtemp_Jul + Maxtemp_Aug', data=trainData).fit()
    predictions =  model.predict(testData) # predict out of sample
    
    myGuesses.append(pd.DataFrame({"maxTemps" : predictions}))
    
    if verbose1 == False:
        descriptions1("maxTemp", model, predictions)       
        
        
    ########## Precip ##########
    model = smf.ols('Yield ~ Year + I(Year**2) + Precip_Jun + Precip_Jul + Precip_Aug', data=trainData).fit()
    predictions =  model.predict(testData) # predict out of sample
    
    myGuesses.append(pd.DataFrame({"precip" : predictions}))
    
    if verbose1 == False:
        descriptions1("Precip", model, predictions)  
        
        
    ########## Precip + maxTemp + comb ##########
    model = smf.ols('Yield ~ Year + I(Year**2) + Precip_Jul + Precip_Aug + Maxtemp_Jul + Maxtemp_Aug + I(Precip_Aug**2) + I(Precip_Jul*Precip_Aug)', data=trainData).fit()
    predictions =  model.predict(testData) # predict out of sample
    
    myGuesses.append(pd.DataFrame({"precip_temp_comb" : predictions}))
    
    if verbose1 == False:
        descriptions1("Precip_Temp_Comb", model, predictions)            
                       
        
    ########## Lasso ##############################        
    model = smf.ols('Yield ~ YearDummy2013 + Year + I(Year**2) + I(Year*Pmdi1_Aug) + I(Year*Mintemp_Aug) + \
                     I(Year*Precip_May) + I(Year*Precip_Aug) + I(Year*Maxtemp_Jun) + I(Year*Maxtemp_Aug)' , data=trainData).fit()
    predictions =  model.predict(testData) # predict out of sample
    
    myGuesses.append(pd.DataFrame({"lasso" : predictions}))
    
    if verbose1 == False:
        descriptions1("lasso", model, predictions)     
    
    
    ########## ARIMA ##########    
    # ARIMA
    series = trainData["Yield"] 
    trainData["Precip_Aug_sq"] = trainData["Precip_Aug"] * trainData["Precip_Aug"] 
    trainData["Year_sq"] = trainData["Year"] * trainData["Year"] 
    
    
    testData["Precip_Aug_sq"] = testData["Precip_Aug"] * testData["Precip_Aug"] 
    testData["Year_sq"] = testData["Year"] * testData["Year"] 
    
    myExog = trainData[["Precip_Aug", "Maxtemp_Aug"]]
    exog_forecast = testData[["Precip_Aug", "Maxtemp_Aug"]]
    
    order1 = sm.tsa.SARIMAX(series, exog=myExog, order=(3, 1, 0), trend='t')
    model = order1.fit()

    predictions = model.forecast(finalYear - testYear, exog=exog_forecast, dynamic= True)
    df1 = pd.DataFrame({"arima" : predictions})
    df1["Year"] = list(range(testYear, 2021))
    df1.set_index("Year", drop = True, inplace=True)
    
    myGuesses.append(df1)
    
    if verbose1 == False:
        descriptions1("ARIMA", model, predictions)    
    
    
    ########## Lasso ##########    
    # Lasso
    mat1 = ["Yield", "Year", "YearDummy2013", "Precip_Aug", "Maxtemp_Aug",  "Maxtemp_Jun", "Precip_Jun", "Maxtemp_Jul", "Precip_Jul"]
    
    matrices = {
        "IOWA":      ["Yield", "Year", "Maxtemp_Jun", "Maxtemp_Jul", "Maxtemp_Aug", "Precip_Jun","Precip_Jul", "Precip_Aug"],
        "INDIANA":   ["Yield", "Year", "YearDummy2013", "Maxtemp_Jun", "Maxtemp_Jul", "Maxtemp_Aug", "Precip_Jun","Precip_Jul", "Precip_Aug"],
        "ILLINOIS":  ["Yield", "Year", "YearDummy2013", "Maxtemp_Jun", "Maxtemp_Jul", "Maxtemp_Aug", "Precip_Jun","Precip_Jul", "Precip_Aug"],
        "MINNESOTA": ["Yield", "Year", "Precip_Jun","Precip_Jul", "Precip_Aug"],
        "OHIO":      ["Yield", "Year","Precip_Jul", "Precip_Aug"]
    }
 
    alphas1 = {
      "IOWA":      5000,
      "INDIANA":   1500,
      "ILLINOIS":  2000,
      "MINNESOTA": 1,  
      "OHIO":      300  
    }
    
    myMinValues = {
      "IOWA":      1e-7,
      "INDIANA":   1e-7,
      "ILLINOIS":  1e-7,
      "MINNESOTA": 1e-7,
      "OHIO":      1e-7  
    }
    
    model, predictions = myLasso(trainData, testData, matrices[state1], alphas1[state1], myMinValues[state1])
    
    df1 = pd.DataFrame({"autolasso" : predictions})
    df1["Year"] = list(range(testYear, 2021))
    df1.set_index("Year", drop = True, inplace=True)
    
    myGuesses.append(df1)
    
    if verbose1 == True:
        descriptions1("AutoLasso", model, predictions)
    
    
    ####Print yield
    stData["Yield"].plot(figsize=(16,6))
    
    
    #####Combine
    stateResults.append(pd.concat(myGuesses, axis=1))
# Out:
# state:  IOWA
# AutoLasso
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Yield   R-squared:                       0.967
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                     165.0
# Date:                Fri, 02 Oct 2020   Prob (F-statistic):           2.34e-52
# Time:                        11:36:41   Log-Likelihood:                -211.15
# No. Observations:                  94   AIC:                             452.3
# Df Residuals:                      79   BIC:                             490.5
# Df Model:                          14
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     -259.4669      9.238    -28.086      0.000    -277.856    -241.078
# Yearsq_Maxtemp_Jun            3.065e-06   4.63e-07      6.615      0.000    2.14e-06    3.99e-06
# Yearsq_Maxtemp_Jul           -1.145e-06   8.26e-07     -1.385      0.170   -2.79e-06       5e-07
# Yearsq_Maxtemp_Aug            7.362e-08   7.73e-07      0.095      0.924   -1.47e-06    1.61e-06
# Yearsq_Precip_Jun            -2.084e-06   8.57e-07     -2.432      0.017   -3.79e-06   -3.78e-07
# Yearsq_Precip_Jul             5.853e-07   1.64e-07      3.577      0.001     2.6e-07    9.11e-07
# Year_Maxtemp_Junsq           -1.231e-05      1e-05     -1.225      0.224   -3.23e-05    7.68e-06
# Year_Maxtemp_Jun_Maxtemp_Jul  8.712e-06   1.82e-05      0.480      0.633   -2.74e-05    4.48e-05
# Year_Maxtemp_Jun_Maxtemp_Aug -5.591e-05   1.54e-05     -3.630      0.001   -8.66e-05   -2.53e-05
# Year_Maxtemp_Julsq           -1.571e-05   1.44e-05     -1.094      0.277   -4.43e-05    1.29e-05
# Year_Maxtemp_Jul_Maxtemp_Aug  4.856e-05   1.71e-05      2.840      0.006    1.45e-05    8.26e-05
# Year_Maxtemp_Jul_Precip_Jun   4.967e-05   2.01e-05      2.465      0.016    9.57e-06    8.98e-05
# Year_Maxtemp_Aug_Precip_Aug   1.539e-05   4.03e-06      3.824      0.000    7.38e-06    2.34e-05
# Year_Precip_Julsq               -0.0001   3.19e-05     -3.703      0.000      -0.000   -5.47e-05
# Year_Precip_Augsq               -0.0001   3.38e-05     -3.062      0.003      -0.000   -3.62e-05
# ==============================================================================
# Omnibus:                       11.193   Durbin-Watson:                   1.546
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               14.759
# Skew:                          -0.573   Prob(JB):                     0.000624
# Kurtosis:                       4.567   Cond. No.                     2.01e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.01e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 0    56.6
# 1    54.2
# 2    51.2
# dtype: float64
# state:  INDIANA
# AutoLasso
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Yield   R-squared:                       0.969
# Model:                            OLS   Adj. R-squared:                  0.964
# Method:                 Least Squares   F-statistic:                     191.9
# Date:                Fri, 02 Oct 2020   Prob (F-statistic):           1.44e-54
# Time:                        11:36:42   Log-Likelihood:                -205.71
# No. Observations:                  94   AIC:                             439.4
# Df Residuals:                      80   BIC:                             475.0
# Df Model:                          13
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     -236.2745      8.779    -26.913      0.000    -253.746    -218.803
# Yearsq_YearDummy2013          6.823e-07   3.42e-07      1.995      0.049    1.57e-09    1.36e-06
# Yearsq_Maxtemp_Jul            2.422e-07   6.19e-07      0.392      0.696   -9.89e-07    1.47e-06
# Yearsq_Maxtemp_Aug            1.083e-06   6.66e-07      1.628      0.108   -2.41e-07    2.41e-06
# Yearsq_Precip_Jun             1.717e-06   1.38e-06      1.242      0.218   -1.04e-06    4.47e-06
# Yearsq_Precip_Jul             5.313e-06   1.58e-06      3.364      0.001    2.17e-06    8.46e-06
# Yearsq_Precip_Aug             2.377e-07   5.85e-08      4.065      0.000    1.21e-07    3.54e-07
# Year_Maxtemp_Jun_Maxtemp_Aug   5.28e-06   1.65e-06      3.201      0.002       2e-06    8.56e-06
# Year_Maxtemp_Jun_Precip_Jul     -0.0001   3.48e-05     -3.074      0.003      -0.000   -3.78e-05
# Year_Maxtemp_Jul_Maxtemp_Aug -6.115e-06   1.44e-05     -0.425      0.672   -3.48e-05    2.25e-05
# Year_Maxtemp_Augsq           -1.213e-05    1.5e-05     -0.808      0.421    -4.2e-05    1.78e-05
# Year_Maxtemp_Aug_Precip_Jun  -2.352e-05   3.07e-05     -0.765      0.446   -8.47e-05    3.76e-05
# Year_Precip_Junsq               -0.0001   3.96e-05     -3.262      0.002      -0.000   -5.03e-05
# Year_Precip_Julsq               -0.0002   5.16e-05     -3.482      0.001      -0.000    -7.7e-05
# ==============================================================================
# Omnibus:                        4.222   Durbin-Watson:                   1.706
# Prob(Omnibus):                  0.121   Jarque-Bera (JB):                4.196
# Skew:                          -0.251   Prob(JB):                        0.123
# Kurtosis:                       3.906   Cond. No.                     1.70e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.7e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 0    56.4
# 1    55.1
# 2    54.9
# dtype: float64
# state:  ILLINOIS
# AutoLasso
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Yield   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     196.5
# Date:                Fri, 02 Oct 2020   Prob (F-statistic):           4.68e-54
# Time:                        11:36:44   Log-Likelihood:                -208.06
# No. Observations:                  94   AIC:                             440.1
# Df Residuals:                      82   BIC:                             470.6
# Df Model:                          11
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     -213.7979      8.433    -25.353      0.000    -230.573    -197.022
# Yearsq_YearDummy2013          1.515e-06   3.43e-07      4.422      0.000    8.33e-07     2.2e-06
# Yearsq_Maxtemp_Jun            2.597e-06   6.28e-07      4.136      0.000    1.35e-06    3.85e-06
# Yearsq_Maxtemp_Jul            -3.69e-07   2.97e-07     -1.242      0.218    -9.6e-07    2.22e-07
# Yearsq_Maxtemp_Aug           -5.979e-07   3.03e-07     -1.974      0.052    -1.2e-06    4.75e-09
# Yearsq_Precip_Jun            -2.136e-06   1.15e-06     -1.863      0.066   -4.42e-06    1.45e-07
# Yearsq_Precip_Jul            -2.048e-07   1.28e-06     -0.160      0.873   -2.75e-06    2.34e-06
# Yearsq_Precip_Aug             1.359e-07   5.29e-08      2.568      0.012    3.07e-08    2.41e-07
# Year_Maxtemp_Junsq           -2.989e-05   7.35e-06     -4.065      0.000   -4.45e-05   -1.53e-05
# Year_Maxtemp_Jul_Maxtemp_Aug  8.917e-06   6.56e-06      1.359      0.178   -4.14e-06     2.2e-05
# Year_Maxtemp_Jul_Precip_Jul   9.349e-06   2.95e-05      0.316      0.752   -4.94e-05    6.81e-05
# Year_Maxtemp_Aug_Precip_Jun   5.229e-05    2.7e-05      1.939      0.056   -1.35e-06       0.000
# ==============================================================================
# Omnibus:                        1.286   Durbin-Watson:                   1.788
# Prob(Omnibus):                  0.526   Jarque-Bera (JB):                1.126
# Skew:                          -0.267   Prob(JB):                        0.569
# Kurtosis:                       2.950   Cond. No.                     1.97e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.97e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 0    57.9
# 1    55.6
# 2    58.6
# dtype: float64
# state:  MINNESOTA
# AutoLasso
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Yield   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.923
# Method:                 Least Squares   F-statistic:                     62.89
# Date:                Fri, 02 Oct 2020   Prob (F-statistic):           5.83e-34
# Time:                        11:36:44   Log-Likelihood:                -202.64
# No. Observations:                  84   AIC:                             439.3
# Df Residuals:                      67   BIC:                             480.6
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   1083.4789    892.352      1.214      0.229    -697.662    2864.620
# Yearsq                        -0.0009      0.001     -1.367      0.176      -0.002       0.000
# Year_Precip_Jun               -0.0044      0.013     -0.346      0.731      -0.030       0.021
# Year_Precip_Aug               -0.0443      0.014     -3.136      0.003      -0.072      -0.016
# Yearcube                    3.395e-07   2.32e-07      1.466      0.147   -1.23e-07    8.02e-07
# Yearsq_Precip_Jun           3.413e-07   6.14e-06      0.056      0.956   -1.19e-05    1.26e-05
# Yearsq_Precip_Jul          -3.959e-06   1.74e-06     -2.271      0.026   -7.44e-06   -4.79e-07
# Yearsq_Precip_Aug           2.299e-05   7.15e-06      3.215      0.002    8.72e-06    3.73e-05
# Year_Precip_Junsq              0.0006      0.001      0.903      0.370      -0.001       0.002
# Year_Precip_Jun_Precip_Jul     0.0015      0.001      2.168      0.034       0.000       0.003
# Year_Precip_Jun_Precip_Aug     0.0002      0.000      1.062      0.292      -0.000       0.000
# Year_Precip_Julsq              0.0019      0.001      1.884      0.064      -0.000       0.004
# Year_Precip_Jul_Precip_Aug  5.845e-05      0.000      0.347      0.730      -0.000       0.000
# Year_Precip_Augsq             -0.0002      0.000     -1.501      0.138      -0.001    7.51e-05
# Precip_Juncube                -0.1138      0.093     -1.227      0.224      -0.299       0.071
# Precip_Jun_Precip_Julsq       -0.5173      0.174     -2.967      0.004      -0.865      -0.169
# Precip_Julcube                -0.1868      0.186     -1.002      0.320      -0.559       0.185
# ==============================================================================
# Omnibus:                        1.079   Durbin-Watson:                   1.920
# Prob(Omnibus):                  0.583   Jarque-Bera (JB):                1.086
# Skew:                          -0.151   Prob(JB):                        0.581
# Kurtosis:                       2.532   Cond. No.                     2.09e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.09e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 0    48.6
# 1    49.3
# 2    52.3
# dtype: float64
# state:  OHIO
# AutoLasso
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Yield   R-squared:                       0.939
# Model:                            OLS   Adj. R-squared:                  0.934
# Method:                 Least Squares   F-statistic:                     187.6
# Date:                Fri, 02 Oct 2020   Prob (F-statistic):           2.79e-49
# Time:                        11:36:45   Log-Likelihood:                -228.32
# No. Observations:                  94   AIC:                             472.6
# Df Residuals:                      86   BIC:                             493.0
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   1598.2072    587.420      2.721      0.008     430.455    2765.959
# Yearsq                        -0.0014      0.000     -3.098      0.003      -0.002      -0.001
# Yearcube                    5.066e-07   1.54e-07      3.298      0.001    2.01e-07    8.12e-07
# Yearsq_Precip_Jul           8.085e-07   3.46e-07      2.339      0.022    1.21e-07     1.5e-06
# Yearsq_Precip_Aug           9.533e-07   3.52e-07      2.706      0.008    2.53e-07    1.65e-06
# Year_Precip_Julsq             -0.0001   5.99e-05     -1.972      0.052      -0.000    9.38e-07
# Year_Precip_Jul_Precip_Aug -3.989e-05      0.000     -0.350      0.727      -0.000       0.000
# Year_Precip_Augsq             -0.0002   8.55e-05     -1.825      0.071      -0.000    1.39e-05
# ==============================================================================
# Omnibus:                       17.743   Durbin-Watson:                   1.581
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.094
# Skew:                          -0.919   Prob(JB):                     9.66e-06
# Kurtosis:                       4.587   Cond. No.                     1.52e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.52e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 0    51.7
# 1    52.4
# 2    51.4
# dtype: float64

# %% [markdown]
# ### Compare models for each state using MAE and MSE
# 1. There are other measures which can be used to assess model performance.
# 2. The basic idea for all measures is the same, how does the model forecast per year compare to the real value in the same year.
# 3. Allows us to compare model performance.

# %%
myResults = []
for index2, j in enumerate(stateResults):

    df1 = j
    print(statesofInterest[index2])
    
    ans1 = []
    for i in df1.columns:
        ans1.append(mse1(df1["Observed"], df1[i]))
    df1.loc["Mse"] = ans1
    
    ans1 = []
    for i in df1.columns:
        ans1.append(mae1(df1["Observed"], df1[i]))   
    df1.loc["Mae"] = ans1

    df1['State'] = statesofInterest[index2]
    pd.set_option('precision', 1)

    myResults.append(df1)
    
for i in myResults:
     display(i)
# Out:
# IOWA
# INDIANA
# ILLINOIS
# MINNESOTA
# OHIO
#       Observed  year_only  year__sq  maxTemps  precip  precip_temp_comb  \
# Year
# 2018      56.0       53.2      54.9      55.0    55.6              56.8
# 2019      55.0       53.6      55.5      56.0    55.1              56.3
# 2020      54.0       54.1      56.1      55.3    54.0              51.8
# Mse        0.0        9.8       5.6       3.8     0.1               7.4
# Mae        0.0       14.1       9.2       7.1     0.6              11.7
#
#       lasso  arima  autolasso State
# Year
# 2018   56.1   57.4       56.6  IOWA
# 2019   55.8   59.0       54.2  IOWA
# 2020   54.5   57.2       51.2  IOWA
# Mse     0.9   28.1        8.9  IOWA
# Mae     2.4   36.6       13.1  IOWA
#       Observed  year_only  year__sq  maxTemps  precip  precip_temp_comb  \
# Year
# 2018      57.5       51.8      53.2      53.1    55.0              54.3
# 2019      51.0       52.2      53.7      53.4    53.6              52.9
# 2020      60.0       52.7      54.3      54.0    53.2              53.6
# Mse        0.0       88.1      58.6      61.2    59.6              54.7
# Mae        0.0      102.4      71.4      74.0    71.5              66.3
#
#       lasso  arima  autolasso    State
# Year
# 2018   56.7   56.4       56.4  INDIANA
# 2019   55.2   55.5       55.1  INDIANA
# 2020   55.4   56.6       54.9  INDIANA
# Mse    39.1   33.5       44.3  INDIANA
# Mae    48.7   42.5       54.6  INDIANA
#       Observed  year_only  year__sq  maxTemps  precip  precip_temp_comb  \
# Year
# 2018      63.5       51.4      53.5      53.7    53.9              53.4
# 2019      54.0       51.8      54.0      54.0    53.1              53.4
# 2020      62.0       52.2      54.5      54.8    54.3              54.7
# Mse        0.0      246.4     156.2     147.2   151.7             155.4
# Mae        0.0      270.5     173.7     164.1   169.9             173.3
#
#       lasso  arima  autolasso     State
# Year
# 2018   58.0   58.4       57.9  ILLINOIS
# 2019   57.1   59.5       55.6  ILLINOIS
# 2020   58.3   59.4       58.6  ILLINOIS
# Mse    53.2   63.2       46.0  ILLINOIS
# Mae    65.5   76.5       56.6  ILLINOIS
#       Observed  year_only  year__sq  maxTemps  precip  precip_temp_comb  \
# Year
# 2018      49.0       46.3      47.6      47.9    47.6              48.5
# 2019      44.0       46.8      48.1      48.4    48.8              49.7
# 2020      52.0       47.2      48.6      49.6    49.7              51.0
# Mse        0.0       37.8      30.3      25.9    30.0              33.4
# Mae        0.0       48.1      39.3      33.8    38.4              40.6
#
#       lasso  arima  autolasso      State
# Year
# 2018   49.5   48.0       48.6  MINNESOTA
# 2019   49.1   51.0       49.3  MINNESOTA
# 2020   50.7   51.5       52.3  MINNESOTA
# Mse    27.9   49.8       28.2  MINNESOTA
# Mae    34.7   58.3       34.1  MINNESOTA
#       Observed  year_only  year__sq  maxTemps  precip  precip_temp_comb  \
# Year
# 2018      56.0       48.4      50.9      50.7    51.8              51.6
# 2019      49.0       48.8      51.4      51.2    52.1              51.6
# 2020      56.0       49.2      52.0      51.3    51.0              51.2
# Mse        0.0      103.0      48.1      55.0    53.0              49.6
# Mae        0.0      117.5      59.7      67.2    65.3              61.5
#
#       lasso  arima  autolasso State
# Year
# 2018   54.7   53.5       51.7  OHIO
# 2019   54.4   53.9       52.4  OHIO
# 2020   52.9   54.4       51.4  OHIO
# Mse    40.1   32.4       51.2  OHIO
# Mae    49.9   41.4       63.5  OHIO

# %% [markdown]
# ### Forecasts
# 1. Year column, these are the years we are forecasting based on model built in previous years.
# 2. State column, all states a forecasted individually.
# 3. Observed column is the real or realized value.
# 4. All other columns are models.

# %%
# Out:
#       Observed  year_only  year__sq  maxTemps  precip  precip_temp_comb  \
# Year
# 2015      56.5       51.1      52.0      53.2    52.8              54.0
# 2016      60.0       51.5      52.5      53.1    54.1              53.2
# 2017      57.0       52.0      53.0      54.9    52.9              54.6
# 2018      56.0       52.4      53.5      53.8    54.5              55.7
# 2019      55.0       52.8      54.0      54.9    53.7              55.2
# 2020      54.0       53.3      54.5      54.0    52.7              50.9
# Mse        0.0      144.7     100.4      67.0    71.2              67.7
# Mae        0.0      170.2     120.4      81.6    89.0              82.9
#
#       lasso  arima  autolasso State
# Year
# 2015   49.0   51.7       52.0  IOWA
# 2016   50.9   50.5       53.8  IOWA
# 2017   49.7   51.6       54.8  IOWA
# 2018   49.9   52.3       54.8  IOWA
# 2019   49.6   52.4       52.0  IOWA
# 2020   48.3   50.3       48.8  IOWA
# Mse   291.3  177.3      102.5  IOWA
# Mae   332.4  207.0      125.0  IOWA
