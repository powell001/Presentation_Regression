# %% [markdown]
# # Overview
#
# 1. Test the tools to download, munge, model and compare various methods to forecast crop yields.
# 1. Flexibility in terms of the years, states, methods and crops used.

# %% [markdown]
# # Goal
#
# 1. Our goal is to build a basic soybean yield model to predict the coming year's yield of that crop.  We will use features such as temperature (avg) and precipitation, US state, NDVI (measure of quality), podcount and test a shift operator to test the hypothesis that technolical change in the last few years has significantly, on linearly, increased yields

# %% [markdown]
# 1. Yearly yields:
#
#     <font size="3"> $$ Yields_{y} \sim Year + PodCount_{m} + State_{y} + Temp_{m} + Precip_{m} + Quality_{m} + Droughts_{m} + Shift + error_{y} $$ </font>

# %% [markdown]
# # Long-term Goals:
# 1. Automate process of modeling yield forecasts and other analyses.
# 2. Incorporate global data.
# 3. Provide a range of forecasts for comparison.

# %% [markdown]
# # Immediate Goals:
# 1. Use US data to forecast soybean yields.
# 2. Automate downloading of data and model scoring.
# 3. Provide figures.
# 4. Test and compare several forecasting methods.

# %% [markdown]
# # <u>Features</u>

# %% [markdown]
# ## Yields (What we want to explain)
#
# ### Hypothsis: Historical yields are a good indicator of future yields.
#
# 1. Plots clearly show a significant trend.
# 2. Nonlinear (quadratic) term picks up rate of increase.
# 3. Look at all major soybean producing states.
# 4. Not accounting for irrigated vs not irrigated, data not good enough.

# %% [markdown]
# ## Pod Count
#
# ### Hypothesis: A good intermediate pod count indicates a good final yield.
#
# 1. We aren't interested in the final pod count, rather the intermediate counts as a way to predict the final yields (which is highly related to the count).
# 2. So we need the pod counts for several intermediate months.
# 3. Available on a monthly basis, starting late in the year (Sep?).

# %% [markdown]
# ## Weather Features
#
# 1. Min
# 2. Max
# 3. Precip
#
# ### These are our main features besides Year.
#
# 1. Bad weather in particular months will damage the soybean crops.
# 2. Try to identify patterns in extreme events.
# 3. Polynomials and interactions.

# %% [markdown]
# ## Quality of Crop
# 1. This is another feature examining the quality of a crop at a particular moment.
# 2. Available on a semi-weekly basis.
# 3. Not many years available and rather spotty.  John suggested that the quality of these measures isn't good, are there other measures?

# %% [markdown]
# ## Drought Measures
# 1. PDSI
# 2. PHDI
# 3. PM
# 4. PZ

# %% [markdown]
# ### Lasso and Ridge regression
#
# 1. Let the model choose the most important features.
# 2. Play with the hyperparameters.

# %% [markdown]
# ## Things to try
#
# 1. Ran initial models to get a feel for the data.
# 2. Tried simple models based on weather variables.
# 3. Add quality features.
# 4. Add irrigated vs non-irrigated.
# 5. Added drought features.
# 6. VIF to eliminate multi-collinearity.
# 3. Try all data, use Lasso, Ridge.

# %% [markdown]
# # <u>Modeling Process</u>

# %% [markdown]
# 1. Notebooks to download each feature and put the data into a "model ready" state.
#     Presentation_01/features
#         a. NASS yield and acre data
#         b. NASS quality measure
#         c. NASS pod count
#         d. NOAA precip, max, min temp
#         e. NOAA drought measure
#     Munged data sent to another file
# 2. A notebook to combine features (joinFeatures.ipynb).
#     Presentation_01/joinFeatures.ipynb
# 3. A notebook to perform model selection, e.g. ridge and lasso regressions (featureSelection.iypnb).
#     Presentation_01/featureSelection.ipynb
# 4. This notebook, which loops over various years and states, performs regressions, and summarize and compares outputs.
#     Presentation_0b1/Project_MainFile.ipynb
# 5. A helper_Functions.ipynb to hold functions that will otherwise obscure more relevant code.
#     Presentation_01/helper_Functions.ipynb

# %% [markdown]
# # <u>Models</u>

# %% [markdown]
# ### Imports and general settings

# %%
import ipynb
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.graphics.regressionplots import plot_leverage_resid2
import matplotlib.pyplot as plt
import warnings
import pandas as pd
warnings.filterwarnings('ignore')
from ipynb.fs.full.joinFeatures import mergedData
from ipynb.fs.full.helper_Functions import descriptions1, mse1, mae1

# %% [markdown]
# ### Import merged data, combine based on year key.

# %%
allData1 = mergedData()
# Out:
# model_allStates_pmdi1.csv
# model_allStates_minTemp1.csv
# model_allStates_precip.csv
# model_allStates_acres.csv
# model_allStates_quality.csv
# model_allStates_zndx1.csv
# model_allStates_pdsi1.csv
# model_allStates_podcount.csv
# model_allStates_yields.csv
# model_allStates_maxTemp1.csv

# %% [markdown]
# ### Add dummy variable

# %%
allData1["YearDummy"] = 0
allData1.loc[allData1.Year > 2013, 'YearDummy'] = 1

# %% [markdown]
# ### Which states and years to train and test

# %%
testYear  = 2018 #build model on years before this year, this is the training set
startYear = 1800 #grab all years
finalYear = 2021

statesofInterest = ['IOWA', 'INDIANA', 'ILLINOIS', 'KANSAS', 'MINNESOTA', 'MISSOURI', 'NEBRASKA', 'NORTH DAKOTA', 'SOUTH DAKOTA', 'OHIO']
#statesofInterest = ['ILLINOIS']

# %% [markdown]
# ### Start loops over model per state

# %%
stateResults = []
verbose1 = False
for index1, state1 in enumerate(statesofInterest):
    myGuesses = []
    
    if verbose1 == False:
        # print("index: ", index1)
        print("state: ", state1)
    
    stData = allData1[allData1["State"] == state1]
    trainData = stData[stData["Year"] < testYear]
    testData = stData[stData["Year"]  >= testYear]
    
    if verbose1 == True:
         print("train: ", trainData.shape)
         print("train: ", testData.shape)    
    
    ########## Real ##########
    myGuesses.append(pd.DataFrame({"Observed": testData["Yield"]}))
    
    ########## Year Only ##########
    model = smf.ols('Yield ~ Year', data=trainData).fit()
    predictions =  model.predict(testData) # predict out of sample()
    
    myGuesses.append(pd.DataFrame({"year_only" : predictions}))
    
    if verbose1 == True:
        descriptions1("year_only", model, predictions)
    
    
    ########## Year + Year² ##########
    model = smf.ols('Yield ~ Year + I(Year**2) + YearDummy', data=trainData).fit()
    predictions =  model.predict(testData) # predict out of sample
    
    myGuesses.append(pd.DataFrame({"year__sq" : predictions}))
    
    if verbose1 == False:
        descriptions1("year_sq", model, predictions)
        
    ########## Max Temps ##########
    model = smf.ols('Yield ~ Year + I(Year**2) + Maxtemp_Jun + Maxtemp_Jul + Maxtemp_Aug', data=trainData).fit()
    predictions =  model.predict(testData) # predict out of sample
    
    myGuesses.append(pd.DataFrame({"maxTemps" : predictions}))
    
    if verbose1 == True:
        descriptions1("maxTemp", model, predictions)       
        
        
    ########## Precip ##########
    model = smf.ols('Yield ~ Year + I(Year**2) + Precip_Jun + Precip_Jul + Precip_Aug', data=trainData).fit()
    predictions =  model.predict(testData) # predict out of sample
    
    myGuesses.append(pd.DataFrame({"precip" : predictions}))
    
    if verbose1 == True:
        descriptions1("Precip", model, predictions)  
        
        
    ########## Precip + maxTemp ##########
    model = smf.ols('Yield ~ Year + I(Year**2) + Precip_Jul + Precip_Aug + Maxtemp_Jul + Maxtemp_Aug', data=trainData).fit()
    predictions =  model.predict(testData) # predict out of sample
    
    myGuesses.append(pd.DataFrame({"precip_temp" : predictions}))
    
    if verbose1 == True:
        descriptions1("Precip_Temp", model, predictions)    
        
        
    ########## Precip + maxTemp + comb ##########
    model = smf.ols('Yield ~ Year + I(Year**2) + Precip_Jul + Precip_Aug + Maxtemp_Jul + Maxtemp_Aug + I(Precip_Aug**2) + I(Precip_Jul*Precip_Aug)', data=trainData).fit()
    predictions =  model.predict(testData) # predict out of sample
    
    myGuesses.append(pd.DataFrame({"precip_temp_comb" : predictions}))
    
    if verbose1 == True:
        descriptions1("Precip_Temp_Comb", model, predictions)            
                       
    ########## Lasso ##############################        
    model = smf.ols('Yield ~ YearDummy + Year  + I(Year**2) + I(Maxtemp_Aug**2) + I(Precip_Jun**3) + I(Precip_Jun*Precip_Jul**2) + I(Precip_Jun*Maxtemp_Jun**2) + \
    I(Precip_Jul**3) + I(Precip_Jul**2 * Precip_Aug) + I(Precip_Jul*Precip_Aug**2) + I(Precip_Jul*Maxtemp_Jun**2)+I(Precip_Aug*Maxtemp_Aug**2)' , data=trainData).fit()
    predictions =  model.predict(testData) # predict out of sample
    
    myGuesses.append(pd.DataFrame({"Lasso" : predictions}))
    
    if verbose1 == True:
        descriptions1("Lasso", model, predictions)  
                
        
    ########## Lasso2 ##############################        
    model = smf.ols('Yield ~ YearDummy + Year + I(Year**2) + I(Year*Pmdi1_Aug) + I(Year*Mintemp_Aug) + \
                     I(Year*Precip_May) + I(Year*Precip_Aug) + I(Year*Maxtemp_Jun) + I(Year*Maxtemp_Aug)' , data=trainData).fit()
    predictions =  model.predict(testData) # predict out of sample
    
    myGuesses.append(pd.DataFrame({"Lasso2" : predictions}))
    
    if verbose1 == True:
        descriptions1("Lasso2", model, predictions)     
    
    ########## ARIMA ##########    
    # ARIMA
    series = trainData["Yield"] 
    order1 = sm.tsa.SARIMAX(series, order=(2, 1, 0), trend='t')
    model = order1.fit()

    predictions = model.forecast(finalYear - testYear)
    df1 = pd.DataFrame({"arima" : predictions})
    df1["Year"] = list(range(testYear, 2021))
    df1.set_index("Year", drop = True, inplace=True)
    
    myGuesses.append(df1)
    
    if verbose1 == True:
        descriptions1("ARIMA", model, predictions)    
    
    ####Print yield
    stData["Yield"].plot()
    
    
    #####Combine
    stateResults.append(pd.concat(myGuesses, axis=1))
# Out:
# state:  IOWA
# year_sq
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Yield   R-squared:                       0.930
# Model:                            OLS   Adj. R-squared:                  0.927
# Method:                 Least Squares   F-statistic:                     397.6
# Date:                Sat, 26 Sep 2020   Prob (F-statistic):           8.75e-52
# Time:                        07:01:50   Log-Likelihood:                -246.52
# No. Observations:                  94   AIC:                             501.0
# Df Residuals:                      90   BIC:                             511.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     1815.8505   2302.817      0.789      0.432   -2759.098    6390.799
# Year            -2.2469      2.340     -0.960      0.340      -6.896       2.402
# I(Year ** 2)     0.0007      0.001      1.145      0.255      -0.001       0.002
# YearDummy        3.7797      2.069      1.827      0.071      -0.331       7.891
# ==============================================================================
# Omnibus:                       29.603   Durbin-Watson:                   2.157
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               57.121
# Skew:                          -1.228   Prob(JB):                     3.95e-13
# Kurtosis:                       5.925   Cond. No.                     2.55e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.55e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Year
# 2018    57.4
# 2019    57.9
# 2020    58.4
# dtype: float64
# state:  INDIANA
# year_sq
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Yield   R-squared:                       0.946
# Model:                            OLS   Adj. R-squared:                  0.944
# Method:                 Least Squares   F-statistic:                     522.7
# Date:                Sat, 26 Sep 2020   Prob (F-statistic):           8.52e-57
# Time:                        07:01:51   Log-Likelihood:                -231.93
# No. Observations:                  94   AIC:                             471.9
# Df Residuals:                      90   BIC:                             482.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     1155.8188   1971.718      0.586      0.559   -2761.344    5072.981
# Year            -1.5709      2.004     -0.784      0.435      -5.551       2.409
# I(Year ** 2)     0.0005      0.001      0.997      0.321      -0.001       0.002
# YearDummy        3.4600      1.772      1.953      0.054      -0.060       6.980
# ==============================================================================
# Omnibus:                       11.885   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               14.199
# Skew:                          -0.665   Prob(JB):                     0.000825
# Kurtosis:                       4.363   Cond. No.                     2.55e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.55e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Year
# 2018    55.4
# 2019    55.9
# 2020    56.4
# dtype: float64
# state:  ILLINOIS
# year_sq
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Yield   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.935
# Method:                 Least Squares   F-statistic:                     446.5
# Date:                Sat, 26 Sep 2020   Prob (F-statistic):           6.68e-54
# Time:                        07:01:51   Log-Likelihood:                -233.62
# No. Observations:                  94   AIC:                             475.2
# Df Residuals:                      90   BIC:                             485.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      801.3946   2007.447      0.399      0.691   -3186.749    4789.538
# Year            -1.1709      2.040     -0.574      0.567      -5.223       2.882
# I(Year ** 2)     0.0004      0.001      0.764      0.447      -0.001       0.001
# YearDummy        7.5586      1.804      4.190      0.000       3.975      11.142
# ==============================================================================
# Omnibus:                       21.424   Durbin-Watson:                   2.157
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.149
# Skew:                          -1.005   Prob(JB):                     1.04e-07
# Kurtosis:                       5.042   Cond. No.                     2.55e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.55e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Year
# 2018    58.3
# 2019    58.7
# 2020    59.2
# dtype: float64
# state:  KANSAS
# year_sq
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Yield   R-squared:                       0.781
# Model:                            OLS   Adj. R-squared:                  0.774
# Method:                 Least Squares   F-statistic:                     106.9
# Date:                Sat, 26 Sep 2020   Prob (F-statistic):           1.46e-29
# Time:                        07:01:52   Log-Likelihood:                -282.52
# No. Observations:                  94   AIC:                             573.0
# Df Residuals:                      90   BIC:                             583.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     2076.3312   3377.377      0.615      0.540   -4633.418    8786.080
# Year            -2.4163      3.432     -0.704      0.483      -9.234       4.402
# I(Year ** 2)     0.0007      0.001      0.799      0.426      -0.001       0.002
# YearDummy        3.3695      3.035      1.110      0.270      -2.660       9.399
# ==============================================================================
# Omnibus:                        1.419   Durbin-Watson:                   1.637
# Prob(Omnibus):                  0.492   Jarque-Bera (JB):                1.269
# Skew:                          -0.129   Prob(JB):                        0.530
# Kurtosis:                       2.493   Cond. No.                     2.55e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.55e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Year
# 2018    40.9
# 2019    41.3
# 2020    41.7
# dtype: float64
# state:  MINNESOTA
# year_sq
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Yield   R-squared:                       0.895
# Model:                            OLS   Adj. R-squared:                  0.891
# Method:                 Least Squares   F-statistic:                     226.3
# Date:                Sat, 26 Sep 2020   Prob (F-statistic):           5.60e-39
# Time:                        07:01:53   Log-Likelihood:                -224.64
# No. Observations:                  84   AIC:                             457.3
# Df Residuals:                      80   BIC:                             467.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     1582.0985   3280.035      0.482      0.631   -4945.380    8109.577
# Year            -1.9869      3.324     -0.598      0.552      -8.603       4.629
# I(Year ** 2)     0.0006      0.001      0.721      0.473      -0.001       0.002
# YearDummy        2.2335      2.237      0.998      0.321      -2.218       6.685
# ==============================================================================
# Omnibus:                        9.578   Durbin-Watson:                   1.797
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                9.516
# Skew:                          -0.700   Prob(JB):                      0.00858
# Kurtosis:                       3.871   Cond. No.                     3.26e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.26e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Year
# 2018    48.9
# 2019    49.4
# 2020    49.8
# dtype: float64
# state:  MISSOURI
# year_sq
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Yield   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.894
# Method:                 Least Squares   F-statistic:                     261.6
# Date:                Sat, 26 Sep 2020   Prob (F-statistic):           2.60e-44
# Time:                        07:01:53   Log-Likelihood:                -251.24
# No. Observations:                  94   AIC:                             510.5
# Df Residuals:                      90   BIC:                             520.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept    -5490.8449   2421.392     -2.268      0.026   -1.03e+04    -680.328
# Year             5.2398      2.460      2.130      0.036       0.352      10.128
# I(Year ** 2)    -0.0012      0.001     -1.982      0.051      -0.002    3.04e-06
# YearDummy        7.4945      2.176      3.444      0.001       3.172      11.817
# ==============================================================================
# Omnibus:                        5.462   Durbin-Watson:                   1.810
# Prob(Omnibus):                  0.065   Jarque-Bera (JB):                4.806
# Skew:                          -0.521   Prob(JB):                       0.0905
# Kurtosis:                       3.374   Cond. No.                     2.55e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.55e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Year
# 2018    47.0
# 2019    47.2
# 2020    47.5
# dtype: float64
# state:  NEBRASKA
# year_sq
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Yield   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     190.7
# Date:                Sat, 26 Sep 2020   Prob (F-statistic):           2.79e-35
# Time:                        07:01:54   Log-Likelihood:                -231.57
# No. Observations:                  80   AIC:                             471.1
# Df Residuals:                      76   BIC:                             480.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     8163.9097   4662.666      1.751      0.084   -1122.594    1.75e+04
# Year            -8.7231      4.721     -1.848      0.069     -18.126       0.679
# I(Year ** 2)     0.0023      0.001      1.951      0.055   -4.84e-05       0.005
# YearDummy        4.6989      2.823      1.664      0.100      -0.924      10.322
# ==============================================================================
# Omnibus:                        4.898   Durbin-Watson:                   1.915
# Prob(Omnibus):                  0.086   Jarque-Bera (JB):                3.902
# Skew:                          -0.426   Prob(JB):                        0.142
# Kurtosis:                       2.333   Cond. No.                     3.64e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.64e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Year
# 2018    59.3
# 2019    60.0
# 2020    60.7
# dtype: float64
# state:  NORTH DAKOTA
# year_sq
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Yield   R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.804
# Method:                 Least Squares   F-statistic:                     103.8
# Date:                Sat, 26 Sep 2020   Prob (F-statistic):           4.34e-26
# Time:                        07:01:55   Log-Likelihood:                -207.99
# No. Observations:                  76   AIC:                             424.0
# Df Residuals:                      72   BIC:                             433.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     -495.4024   4572.822     -0.108      0.914   -9611.156    8620.352
# Year             0.1719      4.625      0.037      0.970      -9.048       9.392
# I(Year ** 2)  4.528e-05      0.001      0.039      0.969      -0.002       0.002
# YearDummy        0.7413      2.444      0.303      0.763      -4.131       5.613
# ==============================================================================
# Omnibus:                        0.956   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.620   Jarque-Bera (JB):                0.432
# Skew:                          -0.107   Prob(JB):                        0.806
# Kurtosis:                       3.301   Cond. No.                     4.07e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.07e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Year
# 2018    36.6
# 2019    37.0
# 2020    37.3
# dtype: float64
# state:  SOUTH DAKOTA
# year_sq
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Yield   R-squared:                       0.858
# Model:                            OLS   Adj. R-squared:                  0.852
# Method:                 Least Squares   F-statistic:                     148.8
# Date:                Sat, 26 Sep 2020   Prob (F-statistic):           2.94e-31
# Time:                        07:01:55   Log-Likelihood:                -213.05
# No. Observations:                  78   AIC:                             434.1
# Df Residuals:                      74   BIC:                             443.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     1667.4450   4240.575      0.393      0.695   -6782.085    1.01e+04
# Year            -2.0377      4.291     -0.475      0.636     -10.588       6.513
# I(Year ** 2)     0.0006      0.001      0.562      0.576      -0.002       0.003
# YearDummy        6.1567      2.414      2.550      0.013       1.347      10.967
# ==============================================================================
# Omnibus:                        1.219   Durbin-Watson:                   1.821
# Prob(Omnibus):                  0.543   Jarque-Bera (JB):                1.050
# Skew:                          -0.053   Prob(JB):                        0.592
# Kurtosis:                       2.441   Cond. No.                     3.84e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.84e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Year
# 2018    46.9
# 2019    47.4
# 2020    47.8
# dtype: float64
# state:  OHIO
# year_sq
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Yield   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     346.0
# Date:                Sat, 26 Sep 2020   Prob (F-statistic):           2.83e-49
# Time:                        07:01:56   Log-Likelihood:                -240.59
# No. Observations:                  94   AIC:                             489.2
# Df Residuals:                      90   BIC:                             499.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     4034.4041   2162.114      1.866      0.065    -261.013    8329.821
# Year            -4.4466      2.197     -2.024      0.046      -8.811      -0.082
# I(Year ** 2)     0.0012      0.001      2.195      0.031       0.000       0.002
# YearDummy        3.0612      1.943      1.576      0.119      -0.799       6.921
# ==============================================================================
# Omnibus:                       10.971   Durbin-Watson:                   1.867
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.228
# Skew:                          -0.745   Prob(JB):                      0.00365
# Kurtosis:                       3.804   Cond. No.                     2.55e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.55e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Year
# 2018    52.9
# 2019    53.4
# 2020    53.9
# dtype: float64

# %% [markdown]
# ### Compare models for each state using MAE and MSE
# 1. There are other measures which can be used to assess model performance.
# 2. The basic idea for all measures is the same, how does the model forecast per year compare to the real value in the same year.
# 3. Allows us to compare model performance.

# %%
myResults = []
for index2, j in enumerate(stateResults):

    df1 = j
    print(statesofInterest[index2])
    
    ans1 = []
    for i in df1.columns:
        ans1.append(mse1(df1["Observed"], df1[i]))
    df1.loc["Mse"] = ans1
    
    ans1 = []
    for i in df1.columns:
        ans1.append(mae1(df1["Observed"], df1[i]))   
    df1.loc["Mae"] = ans1

    df1['State'] = statesofInterest[index2]
    pd.set_option('precision', 1)

    myResults.append(df1)
# Out:
# IOWA
# INDIANA
# ILLINOIS
# KANSAS
# MINNESOTA
# MISSOURI
# NEBRASKA
# NORTH DAKOTA
# SOUTH DAKOTA
# OHIO

# %% [markdown]
# ### Forecasts
# 1. Year column, these are the years we are forecasting based on model built in previous years.
# 2. State column, all states a forecasted individually.
# 3. Observed column is the real or realized value.
# 4. All other columns are models.

# %%
for i in myResults:
     display(i)
# Out:
#       Observed  year_only  year__sq  maxTemps  precip  precip_temp  \
# Year
# 2018      56.0       53.2      57.4      55.0    55.6         55.5
# 2019      55.0       53.6      57.9      56.0    55.1         55.7
# 2020      54.0       54.1      58.4      55.3    54.0         53.6
# Mse        0.0        9.8      29.3       3.8     0.1          1.0
# Mae        0.0       14.1      37.9       7.1     0.6          2.6
#
#       precip_temp_comb  Lasso  Lasso2  arima State
# Year
# 2018              56.8   58.9    56.1   59.4  IOWA
# 2019              56.3   56.4    55.8   60.2  IOWA
# 2020              51.8   53.9    54.5   60.5  IOWA
# Mse                7.4   10.5     0.9   81.2  IOWA
# Mae               11.7   14.8     2.4   96.4  IOWA
#       Observed  year_only  year__sq  maxTemps  precip  precip_temp  \
# Year
# 2018      57.5       51.8      55.4      53.1    55.0         54.2
# 2019      51.0       52.2      55.9      53.4    53.6         53.0
# 2020      60.0       52.7      56.4      54.0    53.2         53.7
# Mse        0.0       88.1      41.4      61.2    59.6         54.0
# Mae        0.0      102.4      52.0      74.0    71.5         65.6
#
#       precip_temp_comb  Lasso  Lasso2  arima    State
# Year
# 2018              54.3   55.8    56.7   54.3  INDIANA
# 2019              52.9   54.0    55.2   56.8  INDIANA
# 2020              53.6   54.8    55.4   56.8  INDIANA
# Mse               54.7   39.0    39.1   54.4  INDIANA
# Mae               66.3   48.9    48.7   66.7  INDIANA
#       Observed  year_only  year__sq  maxTemps  precip  precip_temp  \
# Year
# 2018      63.5       51.4      58.3      53.7    53.9         53.6
# 2019      54.0       51.8      58.7      54.0    53.1         53.6
# 2020      62.0       52.2      59.2      54.8    54.3         54.9
# Mse        0.0      246.4      57.4     147.2   151.7        149.4
# Mae        0.0      270.5      70.1     164.1   169.9        166.8
#
#       precip_temp_comb  Lasso  Lasso2  arima     State
# Year
# 2018              53.4   57.8    58.0   59.1  ILLINOIS
# 2019              53.4   57.0    57.1   60.2  ILLINOIS
# 2020              54.7   58.5    58.3   60.7  ILLINOIS
# Mse              155.4   53.5    53.2   59.1  ILLINOIS
# Mae              173.3   65.7    65.5   70.9  ILLINOIS
#       Observed  year_only  year__sq  maxTemps  precip  precip_temp  \
# Year
# 2018      43.0       37.0      40.9      40.7    40.7         40.9
# 2019      41.5       37.3      41.3      40.3    43.3         41.8
# 2020      44.0       37.7      41.7      40.4    39.5         40.1
# Mse        0.0       93.6      10.2      19.8    28.6         19.9
# Mae        0.0      110.2      14.9      26.9    37.2         26.2
#
#       precip_temp_comb  Lasso  Lasso2  arima   State
# Year
# 2018              40.8   44.6    40.0   41.5  KANSAS
# 2019              40.7   41.9    42.9   42.5  KANSAS
# 2020              40.6   41.6    41.8   42.3  KANSAS
# Mse               17.2    8.6    15.6    6.3  KANSAS
# Mae               23.7   13.0    22.2   10.5  KANSAS
#       Observed  year_only  year__sq  maxTemps  precip  precip_temp  \
# Year
# 2018      49.0       46.3      48.9      47.9    47.6         47.9
# 2019      44.0       46.8      49.4      48.4    48.8         49.1
# 2020      52.0       47.2      49.8      49.6    49.7         50.3
# Mse        0.0       37.8      33.6      25.9    30.0         29.5
# Mae        0.0       48.1      41.2      33.8    38.4         37.3
#
#       precip_temp_comb  Lasso  Lasso2  arima      State
# Year
# 2018              48.5   50.5    49.5   50.3  MINNESOTA
# 2019              49.7   51.0    49.1   51.8  MINNESOTA
# 2020              51.0   54.5    50.7   51.2  MINNESOTA
# Mse               33.4   57.3    27.9   63.4  MINNESOTA
# Mae               40.6   68.3    34.7   73.3  MINNESOTA
#       Observed  year_only  year__sq  maxTemps  precip  precip_temp  \
# Year
# 2018      44.5       42.6      47.0      42.4    41.8         41.7
# 2019      46.0       43.0      47.2      43.3    44.9         44.8
# 2020      51.0       43.4      47.5      43.6    42.8         43.0
# Mse        0.0       70.7      20.2      66.0    75.3         73.6
# Mae        0.0       83.2      27.4      78.2    87.3         85.7
#
#       precip_temp_comb  Lasso  Lasso2  arima     State
# Year
# 2018              41.9   45.3    45.6   48.8  MISSOURI
# 2019              44.3   47.5    46.4   50.2  MISSOURI
# 2020              43.1   48.5    47.3   50.8  MISSOURI
# Mse               72.2    9.1    15.3   36.2  MISSOURI
# Mae               84.4   13.9    20.5   44.9  MISSOURI
#       Observed  year_only  year__sq  maxTemps  precip  precip_temp  \
# Year
# 2018      58.0       53.0      59.3      59.6    58.3         58.7
# 2019      58.5       53.5      60.0      60.2    64.4         63.9
# 2020      60.0       54.0      60.7      57.0    55.1         54.9
# Mse        0.0       86.9       4.5      14.6    59.5         55.9
# Mae        0.0      103.0       8.1      20.9    70.7         67.2
#
#       precip_temp_comb  Lasso  Lasso2  arima     State
# Year
# 2018              60.0   61.5    59.7   60.5  NEBRASKA
# 2019              57.4   60.6    66.2   61.0  NEBRASKA
# 2020              55.4   57.7    57.1   61.7  NEBRASKA
# Mse               26.3   22.0    70.1   15.9  NEBRASKA
# Mae               34.0   29.9    82.4   22.7  NEBRASKA
#       Observed  year_only  year__sq  maxTemps  precip  precip_temp  \
# Year
# 2018      35.0       36.0      36.6      36.3    35.8         35.9
# 2019      31.5       36.4      37.0      36.6    37.3         37.2
# 2020      36.0       36.7      37.3      37.1    37.5         38.3
# Mse        0.0       25.1      34.6      29.0    36.9         38.1
# Mae        0.0       31.6      43.1      36.4    45.1         46.9
#
#       precip_temp_comb  Lasso  Lasso2  arima         State
# Year
# 2018              35.4   37.5    34.9   36.5  NORTH DAKOTA
# 2019              35.7   37.6    36.9   38.6  NORTH DAKOTA
# 2020              38.0   40.6    38.7   37.7  NORTH DAKOTA
# Mse               21.8   64.2    36.5   55.2  NORTH DAKOTA
# Mae               28.4   77.4    44.7   65.4  NORTH DAKOTA
#       Observed  year_only  year__sq  maxTemps  precip  precip_temp  \
# Year
# 2018      45.0       41.4      46.9      43.4    42.6         42.7
# 2019      42.5       41.8      47.4      45.8    49.2         48.7
# 2020      48.0       42.2      47.8      42.9    43.0         42.6
# Mse        0.0       47.9      27.4      39.7    76.4         72.4
# Mae        0.0       58.1      34.4      49.7    90.6         86.2
#
#       precip_temp_comb  Lasso  Lasso2  arima         State
# Year
# 2018              43.2   48.1    44.2   47.3  SOUTH DAKOTA
# 2019              43.5   46.5    51.3   47.2  SOUTH DAKOTA
# 2020              43.0   47.9    46.1   47.6  SOUTH DAKOTA
# Mse               29.6   25.8    81.2   27.4  SOUTH DAKOTA
# Mae               37.5   33.1    92.7   34.7  SOUTH DAKOTA
#       Observed  year_only  year__sq  maxTemps  precip  precip_temp  \
# Year
# 2018      56.0       48.4      52.9      50.7    51.8         51.5
# 2019      49.0       48.8      53.4      51.2    52.1         51.4
# 2020      56.0       49.2      53.9      51.3    51.0         51.0
# Mse        0.0      103.0      33.4      55.0    53.0         50.8
# Mae        0.0      117.5      43.1      67.2    65.3         62.6
#
#       precip_temp_comb  Lasso  Lasso2  arima State
# Year
# 2018              51.6   54.1    54.7   51.6  OHIO
# 2019              51.6   53.7    54.4   53.6  OHIO
# 2020              51.2   53.1    52.9   53.0  OHIO
# Mse               49.6   34.0    40.1   49.4  OHIO
# Mae               61.5   43.5    49.9   61.4  OHIO
