# %% [markdown]
# ## Goal
# 1. Link to dwh (data warehouse)
# 2. Find tables and views
# 3. Query using combinations of sql and python
# 4. Create functions to make queries less cumbersome
# 5. Merge various data sources
# 6. Run more complicated queries
# 7. Import .csv files and perform basic statistics

# %% [markdown]
# ### Import/Write to Oracle

# %%
import cx_Oracle
import os
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

os.environ["ORACLE_HOME"] = "/u01/app/oracle/product/19.3.0_client" 
connection = cx_Oracle.connect("DWH_PYTHON_NL/Mzuu6nIE@nlrtd01ora010.nl.glencore.com/nldwa02.nl.glencore.com")
# connection.close()

# %% [markdown]
# ### Show all tables

# %%
cursor = connection.cursor()
dt1 = cursor.execute("""
            SELECT owner, table_name
            FROM all_tables 
        """)
df = pd.DataFrame(dt1)
df.sort_values(1, inplace=True)
cursor.close()

df.columns = ["owner", "tableName"]
#df[df["owner"] == "DWH_DMT_NL"]
df.head(3)
# Out:
#    owner                  tableName
# 6    SYS  ALL_UNIFIED_AUDIT_ACTIONS
# 5    SYS              AUDIT_ACTIONS
# 50   SYS                    AV_DUAL

# %% [markdown]
# ### Show all views

# %%
cursor = connection.cursor()
dt1 = cursor.execute("""
            SELECT view_name
            FROM all_views
        """)
df = pd.DataFrame(dt1)
df.head(3)
# Out:
#                             0
# 0             ALL_XML_SCHEMAS
# 1            ALL_XML_SCHEMAS2
# 2  V_$ADVISOR_CURRENT_SQLPLAN

# %% [markdown]
# ### Try simple query using BETWEEN dates

# %%
cursor = connection.cursor()
dt1 = cursor.execute("""
                 select TRADE_DATE, MARKET_PRICE
                 from Dst_v_Market_Price_Drv
                 where RIC_CODE = 'SX0'
                 AND TRADE_DATE BETWEEN TO_DATE('2020-08-15','YYYY-MM-DD') AND TO_DATE('2020-09-18', 'YYYY-MM-DD')
                """)
df = pd.DataFrame(dt1)
df.columns = [column[0] for column in cursor.description]
df.head()
# Out:
#   TRADE_DATE  MARKET_PRICE
# 0 2020-08-25        9.2025
# 1 2020-08-27        9.4200
# 2 2020-08-19        9.1400
# 3 2020-08-24        9.0575
# 4 2020-08-17        9.1525

# %% [markdown]
# ### Create Python function to run BETWEEN query

# %%
def test1(a1, b1):
    SQL = """SELECT TRADE_DATE, MARKET_PRICE, RIC_CODE, TRADE_YEAR 
             FROM Dst_v_Market_Price_Drv 
             WHERE RIC_CODE = 'SX0'
             OR RIC_CODE = 'SF1'
             AND TRADE_DATE BETWEEN TO_DATE(:date1,'YYYY-MM-DD') AND TO_DATE(:date2, 'YYYY-MM-DD')"""
    dt1 = cursor.execute(SQL, {'date1' :  a1, 'date2': b1}).fetchall()
    df1 = pd.DataFrame(dt1)
    df1.columns = [column[0] for column in cursor.description]
    return(df1.sort_values('RIC_CODE'))

# %% [markdown]
# #### Run above query

# %%
a1  = '2020-08-15'
b1  = '2020-09-15'
year1 = '2020'
test1(a1, b1).head()
# Out:
#      TRADE_DATE  MARKET_PRICE RIC_CODE  TRADE_YEAR
# 1415 2020-08-26        9.3025      SF1        2020
# 1407 2020-08-27        9.4750      SF1        2020
# 1411 2020-08-24        9.1300      SF1        2020
# 1412 2020-08-19        9.2000      SF1        2020
# 1417 2020-08-28        9.5625      SF1        2020

# %% [markdown]
# ### Try merging two Ric_Codes

# %%
def mergeRics(ric1, ric2, date1, date2):
    SQL = """SELECT TRADE_DATE, MARKET_PRICE, RIC_CODE, TRADE_YEAR 
             FROM Dst_v_Market_Price_Drv 
             WHERE RIC_CODE = :Ric1
             OR RIC_CODE = :Ric2
             AND TRADE_DATE BETWEEN TO_DATE(:date1,'YYYY-MM-DD') AND TO_DATE(:date2, 'YYYY-MM-DD')"""
    
    dt1 = cursor.execute(SQL, {'Ric1': ric1,'Ric2': ric2, 'date1': date1, 'date2': date2}).fetchall()
    df1 = pd.DataFrame(dt1)
    df1.columns = [column[0] for column in cursor.description]
    
    a1 = df1[df1.RIC_CODE == ric1]
    b1 = df1[df1.RIC_CODE == ric2]
    
    result = pd.merge(a1, b1, on='TRADE_DATE', suffixes=('_'+ ric1, '_' + ric2))
    
    
    return(result.sort_values('TRADE_DATE'))

# %%
mr1 = mergeRics('SX0', 'SMZ0', '2020-08-15', '2020-09-15')
mr1[['TRADE_DATE', 'RIC_CODE_SX0', 'MARKET_PRICE_SX0', 'RIC_CODE_SMZ0', 'MARKET_PRICE_SMZ0']]

### Use Dst_v_Market_Price_Drv and select Ric_Code SF1
# Out:
#    TRADE_DATE RIC_CODE_SX0  MARKET_PRICE_SX0 RIC_CODE_SMZ0  MARKET_PRICE_SMZ0
# 4  2020-08-17          SX0            9.1525          SMZ0              305.1
# 7  2020-08-18          SX0            9.1375          SMZ0              303.0
# 2  2020-08-19          SX0            9.1400          SMZ0              302.5
# 6  2020-08-20          SX0            9.0525          SMZ0              300.6
# 8  2020-08-21          SX0            9.0475          SMZ0              297.5
# 3  2020-08-24          SX0            9.0575          SMZ0              297.0
# 0  2020-08-25          SX0            9.2025          SMZ0              300.0
# 9  2020-08-26          SX0            9.2425          SMZ0              299.3
# 1  2020-08-27          SX0            9.4200          SMZ0              303.1
# 5  2020-08-28          SX0            9.5050          SMZ0              309.7
# 10 2020-08-31          SX0            9.5350          SMZ0              312.5
# 21 2020-09-01          SX0            9.5475          SMZ0              310.8
# 15 2020-09-02          SX0            9.6200          SMZ0              310.2
# 14 2020-09-03          SX0            9.6600          SMZ0              312.8
# 20 2020-09-04          SX0            9.6800          SMZ0              317.2
# 16 2020-09-07          SX0            9.6800          SMZ0              317.2
# 18 2020-09-08          SX0            9.7300          SMZ0              314.6
# 19 2020-09-09          SX0            9.7875          SMZ0              318.1
# 12 2020-09-10          SX0            9.7750          SMZ0              317.5
# 11 2020-09-11          SX0            9.9600          SMZ0              324.6
# 13 2020-09-14          SX0            9.9950          SMZ0              322.0
# 17 2020-09-15          SX0            9.9150          SMZ0              319.2

# %% [markdown]
# # Prices

# %%
cursor = connection.cursor()
dt1 = cursor.execute("""
                 select * 
                 from Dst_v_Market_Price_Drv
                 where RIC_CODE = 'SF1'
                """)
df = pd.DataFrame(dt1)
df.columns = [column[0] for column in cursor.description]
df.head(5)
# Out:
#      ETL_REFRESH_DATE RIC_CODE                   ID TRADE_DATE  TRADE_YEAR  \
# 0 2020-09-28 08:26:27      SF1  SF1.201101.20081104 2008-11-04        2008
# 1 2020-09-28 08:26:27      SF1  SF1.201101.20081112 2008-11-12        2008
# 2 2020-09-28 08:26:27      SF1  SF1.201101.20081125 2008-11-25        2008
# 3 2020-09-28 08:26:27      SF1  SF1.201101.20081105 2008-11-05        2008
# 4 2020-09-28 08:26:27      SF1  SF1.201101.20081106 2008-11-06        2008
#
#   DEAL_TYPE EXPIRATION_DATE  MARKET_PRICE  MARKET_PRICE_PREV  \
# 0    FUTURE      2011-01-14       10.0000                NaN
# 1    FUTURE      2011-01-14        9.2500              9.440
# 2    FUTURE      2011-01-14        9.1950              9.165
# 3    FUTURE      2011-01-14        9.5300             10.000
# 4    FUTURE      2011-01-14        9.4625              9.530
#
#    MARKET_PRICE_MOVE  ...  FUTURE_MARKET_PRICE_UNIT_NAME  \
# 0                NaN  ...                       UNKNOWN*
# 1            -0.1900  ...                       UNKNOWN*
# 2             0.0300  ...                       UNKNOWN*
# 3            -0.4700  ...                       UNKNOWN*
# 4            -0.0675  ...                       UNKNOWN*
#
#    HEDGE_COMMODITY_GROUP_NR  HEDGE_COMMODITY_GROUP_CODE  \
# 0                       NaN                   SOYABEANS
# 1                       NaN                   SOYABEANS
# 2                       NaN                   SOYABEANS
# 3                       NaN                   SOYABEANS
# 4                       NaN                   SOYABEANS
#
#    HEDGE_COMMODITY_GROUP_NAME FUTURE_MARKET_NR FUTURE_MARKET_CODE  \
# 0                   Soyabeans              NaN           UNKNOWN*
# 1                   Soyabeans              NaN           UNKNOWN*
# 2                   Soyabeans              NaN           UNKNOWN*
# 3                   Soyabeans              NaN           UNKNOWN*
# 4                   Soyabeans              NaN           UNKNOWN*
#
#    FUTURE_MARKET_NAME FIN_INSTR_TYPE_NR FIN_INSTR_TYPE_CODE  \
# 0            UNKNOWN*               NaN            UNKNOWN*
# 1            UNKNOWN*               NaN            UNKNOWN*
# 2            UNKNOWN*               NaN            UNKNOWN*
# 3            UNKNOWN*               NaN            UNKNOWN*
# 4            UNKNOWN*               NaN            UNKNOWN*
#
#    FIN_INSTR_TYPE_NAME
# 0             UNKNOWN*
# 1             UNKNOWN*
# 2             UNKNOWN*
# 3             UNKNOWN*
# 4             UNKNOWN*
#
# [5 rows x 64 columns]

# %% [markdown]
# ### Use Pandas to select specific rows and columns

# %%
test1 = df[df.EXPIRATION_DATE == '2021-01-14']
test2 = test1[['TRADE_DATE', 'MARKET_PRICE']]
print(test2.head(5))

test2[test2['TRADE_DATE'] == '2020-09-15']
# Out:
#     TRADE_DATE  MARKET_PRICE
# 544 2018-11-21        9.6300
# 545 2018-11-14        9.7200
# 546 2018-11-15        9.7000
# 547 2018-11-16        9.6875
# 548 2018-11-19        9.5700
#      TRADE_DATE  MARKET_PRICE
# 1010 2020-09-15        9.9575

# %% [markdown]
# ### Select a specific price date and plot various prices

# %%
#Premium 
cursor = connection.cursor()
dt1 = cursor.execute("""
    select PRICE_DATE, 
    TRADING_PERIOD, 
    COMMODITY_GROUP_CODE,
    COMMODITY_CODE,
    ORIGIN_CODE,
    MARKET_CODE,
    RESPONSIBLE_SITE_CODE,
    MARKET_PRICE_GROUP_NAME,
    FLAT_PREMIUM_IND,
    RIC_CODE,
    PRICE_UNIT_CODE,
    CURRENCY_CODE,
    BASE_MARKET_PRICE,
    MARKET_PRICE,
    FUTURE_PRICE
    
    from DST_V_MARKET_PRICE_PHS 
    where COMMODITY_GROUP_CODE = 'SOYABEANS' 
    and MARKET_CODE = 'PARANAGUA'
    and FLAT_PREMIUM_IND = 'P' 
    and ORIGIN_CODE = 'BRAZIL'
    and PRICE_DATE = TO_DATE('2020-09-17','YYYY-MM-DD')
    """)
df = pd.DataFrame(dt1)
df.columns = [column[0] for column in cursor.description]
df.head(4)
# Out:
#   PRICE_DATE TRADING_PERIOD COMMODITY_GROUP_CODE COMMODITY_CODE ORIGIN_CODE  \
# 0 2020-09-17         202103            SOYABEANS       BRA SBNS      BRAZIL
# 1 2020-09-17         202101            SOYABEANS       BRA SBNS      BRAZIL
# 2 2020-09-17         202102            SOYABEANS       BRA SBNS      BRAZIL
# 3 2020-09-17         202201            SOYABEANS       BRA SBNS      BRAZIL
#
#   MARKET_CODE RESPONSIBLE_SITE_CODE  \
# 0   PARANAGUA             ROTTERDAM
# 1   PARANAGUA             ROTTERDAM
# 2   PARANAGUA             ROTTERDAM
# 3   PARANAGUA             ROTTERDAM
#
#                       MARKET_PRICE_GROUP_NAME FLAT_PREMIUM_IND RIC_CODE  \
# 0  Soyabeans Bra Sbns Yel Fob Paranagua World                P      SH1
# 1  Soyabeans Bra Sbns Yel Fob Paranagua World                P      SH1
# 2  Soyabeans Bra Sbns Yel Fob Paranagua World                P      SH1
# 3  Soyabeans Bra Sbns Yel Fob Paranagua World                P      SH2
#
#   PRICE_UNIT_CODE CURRENCY_CODE  BASE_MARKET_PRICE  MARKET_PRICE  FUTURE_PRICE
# 0          BUSHEL           USD               0.71          0.71       10.2375
# 1          BUSHEL           USD               1.20          1.20       10.2375
# 2          BUSHEL           USD               0.97          0.97       10.2375
# 3          BUSHEL           USD               0.34          0.34        9.5350

# %%
from datetime import datetime
import matplotlib.pyplot as plt

# Select Brazil
bra1 = df[df["ORIGIN_CODE"]=='BRAZIL']
bra1['Base_Future'] = bra1["BASE_MARKET_PRICE"] + bra1["FUTURE_PRICE"]

#
bra1['TRADING_PERIOD'] = pd.to_datetime(bra1['TRADING_PERIOD'], format='%Y%m')
bra1.set_index("TRADING_PERIOD", drop=True, inplace=True)
bra1.drop_duplicates(inplace=True)
bra1 = bra1.sort_values('TRADING_PERIOD')
bra1 = bra1['2020-10-01':'2021-06-01']

fig, axs = plt.subplots(3, 1, constrained_layout=True, figsize=(12,14))
axs[0].plot(bra1.BASE_MARKET_PRICE,'-', color = 'r')
axs[0].set_title('Base Market Price')
axs[0].set_xlabel('Month')
axs[0].set_ylabel('Value')
fig.suptitle('Soybeans, Brazil, 2020-09-17', fontsize=16)

axs[1].plot(bra1.FUTURE_PRICE, '-', color = 'g')
axs[1].set_title('Future Price')
axs[1].set_xlabel('Month')
axs[1].set_ylabel('Value')

axs[2].plot(bra1.Base_Future, '-', color = 'b')
axs[2].set_title('Market + Future')
axs[2].set_xlabel('Month')
axs[2].set_ylabel('Value')
plt.savefig('test1.png')
plt.show()

# %% [markdown]
# ### Take a look at freight data

# %%
#Premium 

cursor = connection.cursor()
dt1 = cursor.execute("""
    select PRICE_DATE, 
    TRADING_PERIOD, 
    COMMODITY_GROUP_CODE,
    COMMODITY_CODE,
    ORIGIN_CODE,
    MARKET_CODE,
    RESPONSIBLE_SITE_CODE,
    MARKET_PRICE_GROUP_NAME,
    FLAT_PREMIUM_IND,
    RIC_CODE,
    PRICE_UNIT_CODE,
    CURRENCY_CODE,
    BASE_MARKET_PRICE,
    MARKET_PRICE,
    FUTURE_PRICE
    
    from DST_V_MARKET_PRICE_PHS 
    where COMMODITY_GROUP_CODE = 'FREIGHT' 
    and ORIGIN_CODE = 'BRAZIL'
    and PRICE_DATE = TO_DATE('2020-09-10','YYYY-MM-DD')
    """)
df = pd.DataFrame(dt1)
df.columns = [column[0] for column in cursor.description]
df.head(3)
# Out:
#   PRICE_DATE TRADING_PERIOD COMMODITY_GROUP_CODE    COMMODITY_CODE  \
# 0 2020-09-10         202201              FREIGHT  FREIGHT SOYABEAN
# 1 2020-09-10         202111              FREIGHT  FREIGHT SOYABEAN
# 2 2020-09-10         202112              FREIGHT  FREIGHT SOYABEAN
#
#   ORIGIN_CODE MARKET_CODE RESPONSIBLE_SITE_CODE  \
# 0      BRAZIL      BRAZIL             ROTTERDAM
# 1      BRAZIL      BRAZIL             ROTTERDAM
# 2      BRAZIL      BRAZIL             ROTTERDAM
#
#                      MARKET_PRICE_GROUP_NAME FLAT_PREMIUM_IND RIC_CODE  \
# 0  Freight Freight Soyabean Cif Brazil World                F     None
# 1  Freight Freight Soyabean Cif Brazil World                F     None
# 2  Freight Freight Soyabean Cif Brazil World                F     None
#
#   PRICE_UNIT_CODE CURRENCY_CODE BASE_MARKET_PRICE MARKET_PRICE FUTURE_PRICE
# 0              MT           USD              None         None         None
# 1              MT           USD              None         None         None
# 2              MT           USD              None         None         None

# %% [markdown]
# ### Now, try corn instead of soybeans

# %%
#Premium 
cursor = connection.cursor()
dt1 = cursor.execute("""
    select PRICE_DATE, 
    TRADING_PERIOD, 
    COMMODITY_GROUP_CODE,
    COMMODITY_CODE,
    ORIGIN_CODE,
    MARKET_CODE,
    RESPONSIBLE_SITE_CODE,
    MARKET_PRICE_GROUP_NAME,
    FLAT_PREMIUM_IND,
    RIC_CODE,
    PRICE_UNIT_CODE,
    CURRENCY_CODE,
    BASE_MARKET_PRICE,
    MARKET_PRICE,
    FUTURE_PRICE
    
    from DST_V_MARKET_PRICE_PHS 
    where COMMODITY_GROUP_CODE = 'SOYABEANS' 
    and MARKET_CODE = 'PARANAGUA'
    and ORIGIN_CODE = 'BRAZIL'
    and FLAT_PREMIUM_IND = 'P' 
    and COMMODITY_CODE = 'BRA SBNS'
    and TRADING_PERIOD = '202003'
    """)
df = pd.DataFrame(dt1)
df.columns = [column[0] for column in cursor.description]
df.head(5)
# Out:
#   PRICE_DATE TRADING_PERIOD COMMODITY_GROUP_CODE COMMODITY_CODE ORIGIN_CODE  \
# 0 2020-02-24         202003            SOYABEANS       BRA SBNS      BRAZIL
# 1 2020-02-26         202003            SOYABEANS       BRA SBNS      BRAZIL
# 2 2020-03-02         202003            SOYABEANS       BRA SBNS      BRAZIL
# 3 2020-03-04         202003            SOYABEANS       BRA SBNS      BRAZIL
# 4 2020-03-05         202003            SOYABEANS       BRA SBNS      BRAZIL
#
#   MARKET_CODE RESPONSIBLE_SITE_CODE  \
# 0   PARANAGUA             ROTTERDAM
# 1   PARANAGUA             ROTTERDAM
# 2   PARANAGUA             ROTTERDAM
# 3   PARANAGUA             ROTTERDAM
# 4   PARANAGUA             ROTTERDAM
#
#                       MARKET_PRICE_GROUP_NAME FLAT_PREMIUM_IND RIC_CODE  \
# 0  Soyabeans Bra Sbns Yel Fob Paranagua World                P      SH0
# 1  Soyabeans Bra Sbns Yel Fob Paranagua World                P      SH0
# 2  Soyabeans Bra Sbns Yel Fob Paranagua World                P      SH0
# 3  Soyabeans Bra Sbns Yel Fob Paranagua World                P      SH0
# 4  Soyabeans Bra Sbns Yel Fob Paranagua World                P      SH0
#
#   PRICE_UNIT_CODE CURRENCY_CODE  BASE_MARKET_PRICE  MARKET_PRICE  FUTURE_PRICE
# 0          BUSHEL           USD               0.48          0.48        8.7425
# 1          BUSHEL           USD               0.48          0.48        8.8100
# 2          BUSHEL           USD               0.48          0.48        8.9050
# 3          BUSHEL           USD               0.40          0.40        8.9875
# 4          BUSHEL           USD               0.40          0.40        8.8900

# %%
#Premium 
cursor = connection.cursor()
dt1 = cursor.execute("""
    select PRICE_DATE, 
    TRADING_PERIOD, 
    COMMODITY_GROUP_CODE,
    COMMODITY_CODE,
    ORIGIN_CODE,
    MARKET_CODE,
    RESPONSIBLE_SITE_CODE,
    MARKET_PRICE_GROUP_NAME,
    FLAT_PREMIUM_IND,
    RIC_CODE,
    PRICE_UNIT_CODE,
    CURRENCY_CODE,
    BASE_MARKET_PRICE,
    MARKET_PRICE,
    FUTURE_PRICE
    
    from DST_V_MARKET_PRICE_PHS 
    where COMMODITY_GROUP_CODE = 'CORN'  /*Set Commodity*/
    and MARKET_CODE = 'PARANAGUA'
    and ORIGIN_CODE = 'BRAZIL'
    and FLAT_PREMIUM_IND = 'P' 
    and TRADING_PERIOD = '202003'
    """)
df = pd.DataFrame(dt1)
df.columns = [column[0] for column in cursor.description]
df.head(5)
# Out:
#   PRICE_DATE TRADING_PERIOD COMMODITY_GROUP_CODE COMMODITY_CODE ORIGIN_CODE  \
# 0 2019-12-17         202003                 CORN      BRAZ CORN      BRAZIL
# 1 2019-12-05         202003                 CORN      BRAZ CORN      BRAZIL
# 2 2019-12-12         202003                 CORN      BRAZ CORN      BRAZIL
# 3 2019-12-13         202003                 CORN      BRAZ CORN      BRAZIL
# 4 2019-12-18         202003                 CORN      BRAZ CORN      BRAZIL
#
#   MARKET_CODE RESPONSIBLE_SITE_CODE          MARKET_PRICE_GROUP_NAME  \
# 0   PARANAGUA             ROTTERDAM  Corn Braz Corn Fob Santos World
# 1   PARANAGUA             ROTTERDAM  Corn Braz Corn Fob Santos World
# 2   PARANAGUA             ROTTERDAM  Corn Braz Corn Fob Santos World
# 3   PARANAGUA             ROTTERDAM  Corn Braz Corn Fob Santos World
# 4   PARANAGUA             ROTTERDAM  Corn Braz Corn Fob Santos World
#
#   FLAT_PREMIUM_IND RIC_CODE PRICE_UNIT_CODE CURRENCY_CODE  BASE_MARKET_PRICE  \
# 0                P      CH0          BUSHEL           USD               0.82
# 1                P      CH0          BUSHEL           USD               0.82
# 2                P      CH0          BUSHEL           USD               0.82
# 3                P      CH0          BUSHEL           USD               0.82
# 4                P      CH0          BUSHEL           USD               0.82
#
#    MARKET_PRICE  FUTURE_PRICE
# 0          0.82        3.9000
# 1          0.82        3.7675
# 2          0.82        3.7775
# 3          0.82        3.8100
# 4          0.82        3.8700

# %% [markdown]
# ### Now, for one Trading_Period, find all Price_Dates

# %%
df1 = df.set_index("PRICE_DATE")
df1.tail()
# Out:
#            TRADING_PERIOD COMMODITY_GROUP_CODE COMMODITY_CODE ORIGIN_CODE  \
# PRICE_DATE
# 2018-12-31         202003                 CORN      BRAZ CORN      BRAZIL
# 2019-09-20         202003                 CORN      BRAZ CORN      BRAZIL
# 2019-10-10         202003                 CORN      BRAZ CORN      BRAZIL
# 2020-01-03         202003                 CORN      BRAZ CORN      BRAZIL
# 2019-06-05         202003                 CORN      BRAZ CORN      BRAZIL
#
#            MARKET_CODE RESPONSIBLE_SITE_CODE          MARKET_PRICE_GROUP_NAME  \
# PRICE_DATE
# 2018-12-31   PARANAGUA             ROTTERDAM  Corn Braz Corn Fob Santos World
# 2019-09-20   PARANAGUA             ROTTERDAM  Corn Braz Corn Fob Santos World
# 2019-10-10   PARANAGUA             ROTTERDAM  Corn Braz Corn Fob Santos World
# 2020-01-03   PARANAGUA             ROTTERDAM  Corn Braz Corn Fob Santos World
# 2019-06-05   PARANAGUA             ROTTERDAM  Corn Braz Corn Fob Santos World
#
#            FLAT_PREMIUM_IND RIC_CODE PRICE_UNIT_CODE CURRENCY_CODE  \
# PRICE_DATE
# 2018-12-31                P      CH0          BUSHEL           USD
# 2019-09-20                P      CH0          BUSHEL           USD
# 2019-10-10                P      CH0          BUSHEL           USD
# 2020-01-03                P      CH0          BUSHEL           USD
# 2019-06-05                P      CH0          BUSHEL           USD
#
#             BASE_MARKET_PRICE  MARKET_PRICE  FUTURE_PRICE
# PRICE_DATE
# 2018-12-31               0.33          0.33        4.0700
# 2019-09-20               0.05          0.05        3.8175
# 2019-10-10               0.55          0.55        3.9150
# 2020-01-03               0.82          0.82        3.8650
# 2019-06-05               0.26          0.26        4.4200

# %%
df1.sort_index(inplace=True)

fig, axs = plt.subplots(3, 1, constrained_layout=True, figsize=(12,14))
axs[0].plot(df1.BASE_MARKET_PRICE,'-', color = 'r')
axs[0].set_title('Base Market Price')
axs[0].set_xlabel('Month')
axs[0].set_ylabel('Value')
fig.suptitle('Corn, Brazil, Trading Date: 2020-03', fontsize=16)

axs[1].plot(df1.FUTURE_PRICE, '-', color = 'g')
axs[1].set_title('Future Price')
axs[1].set_xlabel('Month')
axs[1].set_ylabel('Value')

axs[2].plot(df1.MARKET_PRICE, '-', color = 'b')
axs[2].set_title('Market Price')
axs[2].set_xlabel('Month')
axs[2].set_ylabel('Value')
plt.savefig('test1.png')
plt.show()

# %% [markdown]
# ### Import csv files and combine features

# %%
mealexp1 = 'meal_exports.xlsx'
exp1 = pd.read_excel(mealexp1, sheet_name="MEAL Exports", usecols=[0, 1], parse_dates=True)
prc1 = pd.read_excel(mealexp1, sheet_name="Meal Prices", usecols=[0, 2], parse_dates=True)
exp1 = exp1[:-1]
exp1['Date'] = pd.to_datetime(exp1['DATE'], format= '%Y-%m')
exp1.drop(columns=["DATE"], inplace=True)
exp1.set_index("Date", inplace=True)
prc1.set_index('Date', inplace=True)

df1 = exp1.join(prc1)
df1.columns = ['Exports', 'MonthPrice']
df1.Exports = df1.Exports/3

df1 = df1.loc['2013-01-01':'2021-01-01']
df1.head()
# Out:
#                 Exports  MonthPrice
# Date
# 2013-01-01  3292.333333       423.1
# 2013-02-01  2774.000000       435.6
# 2013-03-01  2894.333333       400.5
# 2013-04-01  4117.666667       414.5
# 2013-05-01  4826.333333       425.8

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots(figsize=(14,8))
# make a plot
ax.plot(df1.index, df1.Exports, color="red")
# set x-axis label
ax.set_xlabel("Year",fontsize=14)
# set y-axis label
ax.set_ylabel("Exports",color="red",fontsize=14)

# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df1.index, df1["MonthPrice"],color="blue")
ax2.set_ylabel("Prices",color="blue",fontsize=14)
plt.show()

# %%
print('Correlation between Exports and Prices:', df1['Exports'].corr(df1['MonthPrice']))
# Out:
# Correlation between Exports and Prices: -0.2533358535241607
